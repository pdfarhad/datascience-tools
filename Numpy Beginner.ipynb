# %%
import numpy as np 
from matplotlib import pyplot as plt

import math

# %%
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b = np.array((4,5,6))

# %%
b
# Out:
# array([4, 5, 6])

# %%
 a * b
# Out:
# array([ 4, 10, 18])

# %%
a + b
# Out:
# array([5, 7, 9])

# %%
a - b
# Out:
# array([-3, -3, -3])

# %%
a / b
# Out:
# array([ 0.25,  0.4 ,  0.5 ])

# %%
1 / 2
# Out:
# 0.5

# %%
1./2
# Out:
# 0.5

# %%
np.sin(a)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001])

# %%
plt.plot(np.sin(a))

# %%
plt.show()

# %%
a * 5
# Out:
# array([ 5, 10, 15])

# %%
x = np.linspace(0, 2* math.pi, 50 )

# %%
plt.plot(np.sin(x))
plt.show()

# %%
plt.plot?

# %%
plt.plot(x, np.sin(x), 'r-^')
plt.show()

# %%
plt.plot(np.sin(x),'r-o')
plt.show()

# %%
plt.plot(x, np.sin(x), 'r-^',
        x,np.sin(2*x),'b-o')
plt.show()

# %%
plt.scatter(x, np.sin(x))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-fe7c18534556> in <module>()
# ----> 1 plt.scatter(np.sin(x))
#       2 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
plt.scatter(x, np.sin(x))
plt.show()

# %% [markdown]
# ## Colormapped Scatter

# %%
x = rand(200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-eb70d5fb8a58> in <module>()
# ----> 1 x = rand(200)
#
# NameError: name 'rand' is not defined

# %%
from random import randint as rand

# %%
x = rand(1,200)

# %%
y = rand(1,200)

# %%
size = rand(1,200) * 0.30

# %%
color = rand(1,200)

# %%
plt.scatter(x,y,size, color)
plt.colorbar()
plt.show()
