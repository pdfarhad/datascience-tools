# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('upo-salsa pie - Sheet3.csv', header=None)
dataset.head()
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 1 columns):
# 0    42 non-null float64
# dtypes: float64(1)
# memory usage: 416.0 bytes

# %%
dataset.hist(bins=10)
plt.show()

# %%
dataset.hist(cumulative=True, normed=1, bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11596b518>]], dtype=object)

# %%
plt.show()
