# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('upo-salsa-pie.csv')
dataset.fillna(0)
dataset.head()
# Out:
#     OVCAR     MCF   MOLT4     NCI  chemical3
# 0  0.0962  0.0872  0.1274  0.1459        0.0
# 1  0.0962  0.0872  0.1274  0.1459        0.0
# 2  0.7696  0.6975  0.8917  0.9241        0.0
# 3  0.9535  0.8552  1.1072  1.1787        0.0
# 4  2.0202  2.5719  2.4841  1.7996        0.0

# %%
data1 = dataset.OVCAR
data2 = dataset.MCF
data3 = dataset.MOLT4
data4 = dataset.NCI
data5 = dataset.chemical3

# %%
data1.hist( cumulative=True, bins=[0, 10, 20, 30, 40])
plt.show()

# %%
data2.hist( cumulative=True, bins=[0, 10, 20, 30, 40])
plt.show()

# %%
data3.hist( cumulative=True, bins=[0, 10, 20, 30, 40])
plt.show()

# %%
data4.hist( cumulative=True, bins=[0, 10, 20, 30, 40])
plt.show()

# %%
data5.hist( cumulative=True, bins=[0, 10, 20, 30, 40])
plt.show()
